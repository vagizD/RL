# %%
try:
    import google.colab
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB = True
except:
    COLAB = False

# !pip install gymnasium==0.29.1 vizdoom==1.2.4 wandb==0.19.1

# %%
import json
import math
import random
import sys
import os
import time
from collections import deque
from typing import Dict, Type, Any, Tuple, NamedTuple, Optional, Union, Generator, List

import gymnasium as gym
import gymnasium.spaces as spaces
from gymnasium.vector import AsyncVectorEnv, SyncVectorEnv
from gymnasium.wrappers import ResizeObservation, GrayScaleObservation, RecordEpisodeStatistics, TransformReward, \
    FrameStack
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F
from torch import nn
from torch.distributions import Categorical
import vizdoom
from vizdoom import gymnasium_wrapper

try:
    import wandb
    WANDB_IS_AVAILABLE = True
except ImportError:
    WANDB_IS_AVAILABLE = False

os.environ["WANDB_API_KEY"] = "e97ffa4c776cbfb2c0fc0c8b5c97e875139c1d42"

# %% [markdown]
# # Градиент стратегии: REINFORCE
#
# Обозначения:
# - $s$ - состояние, $r$ - вознаграждение, $a$ - действие
# - Условное распределение действий $\pi(a | s)$ - стратегия агента
# - $\tau$ - траектория: $(s_0, r_0, a_0), \dots, (s_T, r_T, a_T)$
# - Отдача $G(\tau) = \sum_{t = 0} ^ T r_t \gamma ^ t$
# - $G_t = r_t + r_{t + 1} \gamma + \dots + r_{T} \gamma ^ {T - t}$
# - Функция полезности состояний: $V(s_{t}) = \mathbb{E}[G_t]$
# - Функция полезности действий: $Q(s_t, a_t) = \mathbb{E}[r_t + \gamma V(s_{t + 1}) | a_t]$
#
# В некоторых задачах для нахождения удовлетворительной стратегии необязательно в точности знать структуру всей среды. Например, в задаче поднятия кубика робототехнической рукой вместо точной аппроксимации полезности $Q(s,a)$ достаточно знать, что выгоднее: двигаться вправо, если кубик справа, и влево в ином случае. С этим же наблюдением связано и предположение, что задача поиска удовлетворительной стратегии проще, нежели задача точной оценки функции полезности.
#
# В данном семинаре познакомимся с простейшим методом прямой оптимизации стратегии REINFORCE, в котором параметры, задающие вероятностную стратегию, изменяются в соответствии с градиентом математического ожидания отдач:
#
# $$J(\theta)= \mathbb{E}[G(\tau)],$$
#
# $$\theta \leftarrow \theta +\alpha \nabla_{\theta} J(\theta),$$
#
# В первом выражении математическое ожидание берется по распределениям начальных состояний, вероятностным функциям переходов и вознаграждений среды, а также по вероятностной стратегии агента $\pi_\theta$. Благодаря теореме о существовании стационарного распределения марковской цепи, это выражение может быть переписано через стационарное распределение $d^\pi$ посещения состояний в среде:
#
# $$J(\theta)= \mathbb{E}_{s \sim d^\pi}[V^{\pi}(s)] = \mathbb{E}_{s \sim d^\pi, a \sim \pi(s)} [Q^{\pi}(s, a)] =: \mathbb{E}_\pi [Q^{\pi}(s, a)].$$
#
# Метод REINFORCE также использует теорему о градиенте стратегии, на основе которой построено целое семейство алгоритмов прямой оптимизации стратегии и актор-критиков. Теорема о градиенте стратегии связывает градиент целевой функции $J$ и градиент самой стратегии:
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [Q^\pi(s, a) \nabla_\theta \ln \pi_\theta(a \vert s)]$$
#
# Для оценки полезности действий $Q^\pi(s, a)$ REINFORCE использует несмещенную Монте-Карло оценку на основе полученных в среде отдач $G_t$ (за некоторое фиксированное число эпизодов в среде). С учетом этого обновление весов осуществляется по правилу:
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [G_t \nabla_\theta \ln \pi_\theta(a_t \vert s_t)]$$
#
# Более подробное (но все равно короткое) описание градиента стратегии, и в частности REINFORCE, можно посмотреть в [блоге Lilian Weng из OpenAI](https://lilianweng.github.io/posts/2018-04-08-policy-gradient/#policy-gradient), либо полноценно разобраться в соответствующей секции классического учебника Саттона и Барто.

# %% [markdown]
# ### Environment: Vizdoom
# Среда для экспериментов: **Vizdoom**. Задача: **VizdoomCorridor-v0**.
#
# Карта представляет собой коридор со стреляющими противниками по обеим сторонам. Зелёная броня размещена на противоположном конце коридора. Цель агента — добраться до предмета. Награда пропорциональна (отрицательна или положительна) изменению расстояния между игроком и жилетом.
# - Вознаграждение: +dX за приближение к броне, -dX за отдаление от брони, -100 за смерть.
# - Агенту доступны 7 действий: движение вперед/назад/влево/вправо, поворот влево/вправо, стрельба.
# - Ограничение по времени: 2100 шагов
#
# Для ускорения обучения агента рассматриваем самый простой уровень сложности `doom_skill = 1`.

# %%
def create_vizdoom_config(verbose=False):
    # Создаёт файл сценария VizdoomCorridor с уровнем сложности doom_skill = 1

    deadly_corridor_doom_skill_1 = """
    # Lines starting with # are treated as comments (or with whitespaces+#).
    # It doesn't matter if you use capital letters or not.
    # It doesn't matter if you use underscore or camel notation for keys, e.g. episode_timeout is the same as episodeTimeout.
    """
    deadly_corridor_doom_skill_1 += f"\ndoom_scenario_path = {os.path.relpath(os.path.dirname(vizdoom.__file__))}/scenarios/deadly_corridor.wad\n"
    deadly_corridor_doom_skill_1 += """
    # Skill 5 is recommended for the scenario to be a challenge.
    doom_skill = 1

    # Rewards
    death_penalty = 100
    #living_reward = 0

    # Rendering options
    screen_resolution = RES_320X240
    screen_format = CRCGCB
    render_hud = true
    render_crosshair = false
    render_weapon = true
    render_decals = false
    render_particles = false
    window_visible = true

    episode_timeout = 2100

    # Available buttons
    available_buttons =
      {
        MOVE_LEFT
        MOVE_RIGHT
        ATTACK
        MOVE_FORWARD
        MOVE_BACKWARD
        TURN_LEFT
        TURN_RIGHT
      }

    # Game variables that will be in the state
    available_game_variables = { HEALTH }

    mode = PLAYER
    """

    config_file_name = f'deadly_corridor_doom-skill-1.cfg'
    with open(config_file_name, 'w') as file_obj:
        print(deadly_corridor_doom_skill_1, file=file_obj)

    if verbose:
        print(deadly_corridor_doom_skill_1)

    return os.path.realpath(config_file_name)


def source_env_info():
    config_file_path = create_vizdoom_config()
    env = gym.make('VizdoomCorridor-v0', **{'scenario_file': config_file_path})
    obs, _ = env.reset()
    plt.imshow(obs['screen'])
    plt.show()
    print(env.env.env.spec.kwargs)

source_env_info()
# Out:
# /home/vagiz/Desktop/desktop_vagiz/HSE/Programming/RL/.venv/lib/python3.12/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# /home/vagiz/Desktop/desktop_vagiz/HSE/Programming/RL/.venv/lib/python3.12/site-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# {'scenario_file': '/home/vagiz/Desktop/desktop_vagiz/HSE/Programming/RL/practices/prac5/deadly_corridor_doom-skill-1.cfg'}

# %% [markdown]
# ### Wrappers

# %%
class ImageExtractorWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        self.observation_space = env.observation_space['screen']

    def observation(self, observation: Dict) -> np.ndarray:
        return observation['screen']


def make_env():
    config_file_path = create_vizdoom_config()
    env = gym.make('VizdoomCorridor-v0', **{'scenario_file': config_file_path})
    env = ImageExtractorWrapper(env)
    env = GrayScaleObservation(env)
    env = ResizeObservation(env, shape=84)
    env = FrameStack(env, num_stack=3)
    env = RecordEpisodeStatistics(env)
    env = TransformReward(env, f=lambda reward: reward / 100.)

    return env


def wrapped_env_info():
    config_file_path = create_vizdoom_config()
    env = make_env()
    env.reset()
    terminated = False
    while not terminated:
        obs, reward, terminated, truncated, info = env.step(env.action_space.sample())

    fig, axes = plt.subplots(1, 3, figsize=(12, 3))
    for ax, frame in zip(axes, obs):
        ax.imshow(frame, cmap='gray')

    print('Наблюдение - стек из 3х последовательных изображений 84х84 в оттенках серого, shape:', obs.shape)
    plt.show()
    print('info на последнем шаге содержит статистику эпизода: r - суммарное вознаграждение, l - длина эпизода, t - продолжительность эпизода в секундах\n', info)

DEMO_WRAPPED_ENV = True
if DEMO_WRAPPED_ENV:
    wrapped_env_info()
# Out:
# Наблюдение - стек из 3х последовательных изображений 84х84 в оттенках серого, shape: (3, 84, 84)
# info на последнем шаге содержит статистику эпизода: r - суммарное вознаграждение, l - длина эпизода, t - продолжительность эпизода в секундах
#  {'episode': {'r': array([-102.22798], dtype=float32), 'l': array([298], dtype=int32), 't': array([0.132812], dtype=float32)}}

# %% [markdown]
# ### Misc

# %%
def set_seed_everywhere(seed: int, using_cuda: bool = False) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    if using_cuda:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# # 1 REINFORCE

# %% [markdown]
# ### Policy
# Основные компоненты ReinforcePolicy:
# - `features_extractor` - свёрточный энкодер, кодирующий изображения в латентный вектор
# - `action_net` - полносвязный слой, который выдаёт логиты действий для предсказания вероятностей

# %% [markdown]
# ![policy](data:image/png;base64,...)

# %%
class Encoder(nn.Module):
    def __init__(
            self,
            observation_space: gym.Space,
            features_dim: int = 512,
    ) -> None:
        super().__init__()
        self.features_dim = features_dim
        n_input_channels = observation_space.shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=8, stride=4, padding=0),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=0),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.Flatten(),
        )

        with torch.no_grad():
            n_flatten = self.cnn(torch.as_tensor(observation_space.sample()[None]).float()).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))


class ReinforcePolicy(nn.Module):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space, lr: float,
                 optimizer_class: Type[torch.optim.Optimizer] = torch.optim.RMSprop,
                 optimizer_kwargs: Dict[str, Any] = {'eps': 1e-5},):
        super().__init__()
        self.observation_space = observation_space
        self.action_space = action_space
        self.lr = lr
        self.optimizer_class = optimizer_class
        self.optimizer_kwargs = dict(optimizer_kwargs)
        self.features_extractor = self.make_features_extractor()
        self.action_net = nn.Linear(self.features_extractor.features_dim, self.action_space.n)
        self.optimizer = self.optimizer_class(self.parameters(), lr=self.lr, **self.optimizer_kwargs)

    def make_features_extractor(self):
        return Encoder(self.observation_space)

    def extract_features(self, obs: torch.Tensor) -> torch.Tensor:
        obs = obs.float() / 255.
        features = self.features_extractor(obs)

        return features

    def forward(self, obs: torch.Tensor, deterministic: bool = False) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)

        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        actions = distribution.mode() if deterministic else distribution.sample()
        actions = actions.reshape((-1, *self.action_space.shape))

        return {'features': features, 'action': actions}

    def evaluate_actions(self, obs: torch.Tensor, actions_taken: torch.Tensor) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)
        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        log_prob = distribution.log_prob(actions_taken)
        entropy = distribution.entropy()

        return {'features': features, 'log_prob': log_prob, 'entropy': entropy}

    def set_training_mode(self, mode: bool) -> None:
        self.train(mode)

# %% [markdown]
# ### Buffer
# В буфере хранятся траектории, собранные агентом. Также в буфере производится вычисление частичных отдач по траекториям.

# %%
class BufferSamples(NamedTuple):
    observations: torch.Tensor
    actions: torch.Tensor
    returns: torch.Tensor


class Buffer:
    def __init__(
            self,
            gamma: float = 0.99,
            device: Union[torch.device, str] = "cpu",
    ):
        self.device = torch.device(device)
        self.gamma = gamma
        self.observations = None
        self.actions = None
        self.rewards = None
        self.returns = None

    def reset(self) -> None:
        self.observations = []
        self.actions = []
        self.rewards = []
        self.returns = None

    def size(self) -> int:
        return len(self.actions)

    def add(
            self,
            obs: np.ndarray,
            action: int,
            reward: float,
    ) -> None:
        self.observations.append(obs)
        self.actions.append(action)
        self.rewards.append(reward)

    def to_torch(self, array: np.ndarray) -> torch.Tensor:
        return torch.tensor(array, device=self.device)

    def _get_samples(
            self,
            batch_inds: np.ndarray,
    ) -> BufferSamples:
        observations = self.to_torch(self.observations[batch_inds])
        actions = self.to_torch(self.actions[batch_inds])
        returns = self.to_torch(self.returns[batch_inds])

        return BufferSamples(observations=observations, actions=actions, returns=returns)

    def get(self) -> BufferSamples:
        buffer_size = self.size()
        indices = np.random.permutation(buffer_size)
        self.observations = np.asarray(self.observations)
        self.actions = np.asarray(self.actions)
        self.returns = np.asarray(self.returns, dtype=np.float32)

        return self._get_samples(indices)

    def compute_returns(self) -> None:
        returns = [None] * len(self.rewards)
        reward_to_go = 0
        for step in reversed(range(len(self.rewards))):
            reward_to_go = self.rewards[step] + self.gamma * reward_to_go
            returns[step] = reward_to_go

        self.returns = returns

# %% [markdown]
# ### Обучение стратегии по методу REINFORCE
# - Метод `learn`: реализует основной цикл RL-обучения: чередование фазы сбора данных (траекторий) агентом в среде - `collect_rollouts` и фазы обучения агента - `train`.
# - Метод `collect_rollouts`: агент выполняет действия в среде согласно текущей стратегии, собирая триплеты **<observation, action, reward>** в буфер
# - Метод `train`: обучение на собранных данных. Функция потерь состоит из двух слагаемых: градиент стратегии и энтропийная регуляризация. Энтропийная регуляризация делает стратегию более стохастичной, т.е. более устойчивой к шуму, помогает исследовать среду, предотвращает сходимость к субоптимальному решению (особенно в средах с дискретными действиями)

# %% [markdown]
# ![learn](data:image/png;base64,...)

# %% [markdown]
# ![reinforce](data:image/png;base64,...)

# %%
class Reinforce:
    def __init__(
            self,
            env: gym.Env,
            learning_rate: float = 2.5e-4,
            gamma: float = 0.99,
            ent_coef: float = 0.001,
            max_grad_norm: float = 0.5,
            stats_window_size: int = 10,
            policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
            policy_kwargs: Optional[Dict[str, Any]] = None,
            buffer_class: Type[Buffer] = Buffer,
            buffer_kwargs: Optional[Dict[str, Any]] = None,
            seed: Optional[int] = None,
            device: Union[torch.device, str] = "cuda",
    ):
        self.device = device if isinstance(device, torch.device) else torch.device(device)
        print(f"Using {self.device} device")

        self.policy_kwargs = {} if policy_kwargs is None else policy_kwargs

        self.num_timesteps = 0
        self._num_timesteps_at_start = 0
        self._episode_num = 0
        self.seed = seed
        self.start_time = 0.0
        self.learning_rate = learning_rate
        self._last_obs = None
        self._stats_window_size = stats_window_size
        self.ep_info_buffer = deque(maxlen=self._stats_window_size)
        self._n_updates = 0

        self.observation_space = env.observation_space
        self.action_space = env.action_space
        self.env = env

        self.n_steps = None
        self.gamma = gamma
        self.ent_coef = ent_coef
        self.max_grad_norm = max_grad_norm
        self.log_dict = {}

        self.set_random_seed(self.seed)
        self.buffer_class = buffer_class
        self.buffer_kwargs = {} if buffer_kwargs is None else buffer_kwargs
        self.buffer = self.buffer_class(
            device=self.device,
            gamma=self.gamma,
            **self.buffer_kwargs,
        )
        self.policy_class = policy_class
        self.policy = self.policy_class(
            self.observation_space, self.action_space, self.learning_rate, **self.policy_kwargs
        )
        self.policy = self.policy.to(self.device)

    def _update_info_buffer(self, info: Dict[str, Any]) -> None:
        # Collect statistics
        assert self.ep_info_buffer is not None

        ep_info = info.get("episode")
        if ep_info is not None:
            self.ep_info_buffer.append(ep_info)

    def set_random_seed(self, seed: Optional[int] = None) -> None:
        if seed is None:
            return
        set_seed_everywhere(seed, using_cuda=self.device.type == torch.device("cuda").type)
        self.action_space.seed(seed)
        self.observation_space.seed(seed)

    def collect_rollouts(
            self,
            env,
            buffer: Buffer,
    ):
        self.policy.set_training_mode(False)
        self._last_obs, _ = self.env.reset()
        self._last_obs = np.array(self._last_obs)
        assert self._last_obs is not None, "No previous observation was provided"

        buffer.reset()
        terminated = False
        while not terminated:
            with torch.no_grad():
                obs_tensor = torch.as_tensor(self._last_obs, device=self.device)
                action = self.policy(obs_tensor.unsqueeze(0))['action']
            action = action.item()
            new_obs, reward, terminated, truncated, info = env.step(action)
            assert not truncated, 'Episode truncation must be off as we want to use Monte Carlo estimation'

            self.num_timesteps += 1
            self._episode_num += int(terminated)
            buffer.add(
                self._last_obs,
                action,
                reward,
            )

            self._last_obs = np.array(new_obs)
            self._update_info_buffer(info)

        buffer.compute_returns()

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']
        returns = rollout_data.returns

        # Policy gradient loss
        policy_loss = -(returns * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        loss = policy_loss + entropy_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates)
        ])

    def get_current_mean_return(self) -> float:
        if len(self.ep_info_buffer) == 0:
            return -math.inf

        return np.mean(np.concatenate([ep_info["r"] for ep_info in self.ep_info_buffer])).item()

    def _dump_logs(self, iteration: int) -> None:
        assert self.ep_info_buffer is not None

        time_elapsed = max((time.time_ns() - self.start_time) / 1e9, sys.float_info.epsilon)
        fps = int((self.num_timesteps - self._num_timesteps_at_start) / time_elapsed)
        self.log_dict["time/iterations"] = iteration
        if len(self.ep_info_buffer) > 0 and len(self.ep_info_buffer[0]) > 0:
            self.log_dict["rollout/ep_rew_mean"] = self.get_current_mean_return()
            self.log_dict["rollout/ep_len_mean"] = np.mean(
                np.concatenate([ep_info["l"] for ep_info in self.ep_info_buffer])).item()

        self.log_dict["time/fps"] = fps
        self.log_dict["time/time_elapsed"] = int(time_elapsed)
        self.log_dict["global_step"] = self.num_timesteps
        self.log_dict["num_episodes"] = self._episode_num
        print(json.dumps(self.log_dict, sort_keys=True, indent=4))

        if WANDB_IS_AVAILABLE and wandb.run is not None:
            wandb.log(self.log_dict)

    def learn(
            self,
            max_timesteps: int,
            expected_return: float,
            log_interval: int = 1000,
            save_checkpoint_path: str = None,
            save_checkpoint_interval: int = 5000,
    ) -> None:
        assert self.env is not None

        self.start_time = time.time_ns()
        self.num_timesteps = 0
        self._episode_num = 0
        self._num_timesteps_at_start = 0
        log_interval = log_interval or math.inf
        if save_checkpoint_path is None or save_checkpoint_interval is None or not COLAB:
            save_checkpoint_interval = math.inf

        next_log_step = self.num_timesteps + log_interval
        next_save_step = self.num_timesteps + save_checkpoint_interval

        if self._last_obs is None:
            self._last_obs, _ = self.env.reset(seed=self.seed)

        iteration = 0
        while True:
            if self.get_current_mean_return() >= expected_return:
                print('Решено!')
                break

            if self.num_timesteps >= max_timesteps:
                print(f'Задача не решена за {max_timesteps} шагов')
                break

            self.collect_rollouts(self.env, self.buffer, )
            iteration += 1

            if self.num_timesteps >= next_log_step:
                assert self.ep_info_buffer is not None
                self._dump_logs(iteration)
                next_log_step += log_interval

            if self.num_timesteps >= next_save_step:
                next_save_step += save_checkpoint_interval
                checkpoint = {'policy': self.policy.state_dict(), 'optimizer': self.policy.optimizer.state_dict(),
                              'num_timesteps': self.num_timesteps, 'episode_num': self._episode_num,
                              'ep_info_buffer': self.ep_info_buffer}
                os.makedirs(save_checkpoint_path, exist_ok=True)
                torch.save(checkpoint, os.path.join(save_checkpoint_path, 'checkpoint.pt'))

            self.train()

# %%
def run_algorithm(algorithm_class, algorithm_kwargs, use_wandb, wandb_kwargs, learn_kwargs):
    env = make_env()
    model = algorithm_class(env, **algorithm_kwargs)
    if use_wandb:
        config = {}
        config.update(algorithm_kwargs)
        config.update(learn_kwargs)
        config.update(wandb_kwargs.get('config', {}))
        wandb_kwargs['config'] = config
        if wandb.run is not None:
            wandb.finish()

        wandb.init(**wandb_kwargs)

    model.learn(**learn_kwargs)
    if use_wandb:
        wandb.finish()

# %%
run_algorithm(
    algorithm_class=Reinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                      save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce',)
)
# Out:
# Using cuda device
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: ulaelfray. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/home/vagiz/Desktop/desktop_vagiz/HSE/Programming/RL/practices/prac5/wandb/run-20251021_225910-eifpmtip</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/eifpmtip' target="_blank">reinforce</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/eifpmtip' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/eifpmtip</a>
# /tmp/ipykernel_67619/3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# /tmp/ipykernel_67619/3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1006,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 335.3333333333333,
#     "rollout/ep_rew_mean": -76.22675323486328,
#     "time/fps": 733,
#     "time/iterations": 3,
#     "time/time_elapsed": 1,
#     "train/entropy": 2.0789313316345215,
#     "train/entropy_loss": -0.0020789315458387136,
#     "train/grad_norm": 0.012465433217585087,
#     "train/loss": -0.21674229204654694,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": -0.21466335654258728
# }
# {
#     "global_step": 2193,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 365.5,
#     "rollout/ep_rew_mean": -68.12448120117188,
#     "time/fps": 864,
#     "time/iterations": 6,
#     "time/time_elapsed": 2,
#     "train/entropy": 2.0788791179656982,
#     "train/entropy_loss": -0.0020788791589438915,
#     "train/grad_norm": 0.02547721564769745,
#     "train/loss": -0.5018758177757263,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": -0.49979695677757263
# }
# {
#     "global_step": 4293,
#     "num_episodes": 7,
#     "rollout/ep_len_mean": 613.2857142857143,
#     "rollout/ep_rew_mean": -54.66374969482422,
#     "time/fps": 957,
#     "time/iterations": 7,
#     "time/time_elapsed": 4,
#     "train/entropy": 2.07682728767395,
#     "train/entropy_loss": -0.0020768274553120136,
#     "train/grad_norm": 0.01800844632089138,
#     "train/loss": -0.3258723318576813,
#     "train/n_updates": 6,
#     "train/policy_gradient_loss": -0.32379549741744995
# }
# {
#     "global_step": 4699,
#     "num_episodes": 8,
#     "rollout/ep_len_mean": 587.375,
#     "rollout/ep_rew_mean": -55.242332458496094,
#     "time/fps": 952,
#     "time/iterations": 8,
#     "time/time_elapsed": 4,
#     "train/entropy": 2.0744786262512207,
#     "train/entropy_loss": -0.0020744786597788334,
#     "train/grad_norm": 0.005877301096916199,
#     "train/loss": 0.02499345876276493,
#     "train/n_updates": 7,
#     "train/policy_gradient_loss": 0.027067936956882477
# }
# {
#     "global_step": 5211,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 579.0,
#     "rollout/ep_rew_mean": -61.15208435058594,
#     "time/fps": 951,
#     "time/iterations": 9,
#     "time/time_elapsed": 5,
#     "train/entropy": 2.0750699043273926,
#     "train/entropy_loss": -0.0020750700496137142,
#     "train/grad_norm": 0.03360453248023987,
#     "train/loss": -0.28467050194740295,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": -0.2825954258441925
# }
# {
#     "global_step": 6095,
#     "num_episodes": 12,
#     "rollout/ep_len_mean": 547.6,
#     "rollout/ep_rew_mean": -44.77339172363281,
#     "time/fps": 959,
#     "time/iterations": 12,
#     "time/time_elapsed": 6,
#     "train/entropy": 2.05668044090271,
#     "train/entropy_loss": -0.0020566806197166443,
#     "train/grad_norm": 0.04441637918353081,
#     "train/loss": -0.5882146954536438,
#     "train/n_updates": 11,
#     "train/policy_gradient_loss": -0.586158037185669
# }
# {
#     "global_step": 7173,
#     "num_episodes": 18,
#     "rollout/ep_len_mean": 247.4,
#     "rollout/ep_rew_mean": 934.3567504882812,
#     "time/fps": 968,
#     "time/iterations": 18,
#     "time/time_elapsed": 7,
#     "train/entropy": 1.2809942745661829e-05,
#     "train/entropy_loss": -1.2809943328306872e-08,
#     "train/grad_norm": 0.000575871265027672,
#     "train/loss": 5.8558775890560355e-06,
#     "train/n_updates": 17,
#     "train/policy_gradient_loss": 5.868687367183156e-06
# }
# {
#     "global_step": 8000,
#     "num_episodes": 23,
#     "rollout/ep_len_mean": 168.3,
#     "rollout/ep_rew_mean": 2093.998046875,
#     "time/fps": 976,
#     "time/iterations": 23,
#     "time/time_elapsed": 8,
#     "train/entropy": 1.1486236871860456e-05,
#     "train/entropy_loss": -1.1486237738722593e-08,
#     "train/grad_norm": 0.0004138773074373603,
#     "train/loss": 3.0087542199908057e-06,
#     "train/n_updates": 22,
#     "train/policy_gradient_loss": 3.0202404559531715e-06
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▄▅▅▆▇█</td></tr><tr><td>num_episodes</td><td>▁▂▂▃▃▄▆█</td></tr><tr><td>rollout/ep_len_mean</td><td>▄▄██▇▇▂▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▄█</td></tr><tr><td>time/fps</td><td>▁▅▇▇▇███</td></tr><tr><td>time/iterations</td><td>▁▂▂▃▃▄▆█</td></tr><tr><td>time/time_elapsed</td><td>▁▂▄▄▅▆▇█</td></tr><tr><td>train/entropy</td><td>██████▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁██</td></tr><tr><td>train/grad_norm</td><td>▃▅▄▂▆█▁▁</td></tr><tr><td>train/loss</td><td>▅▂▄█▄▁██</td></tr><tr><td>train/n_updates</td><td>▁▂▂▃▃▄▆█</td></tr><tr><td>train/policy_gradient_loss</td><td>▅▂▄█▄▁██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>8000</td></tr><tr><td>num_episodes</td><td>23</td></tr><tr><td>rollout/ep_len_mean</td><td>168.3</td></tr><tr><td>rollout/ep_rew_mean</td><td>2093.99805</td></tr><tr><td>time/fps</td><td>976</td></tr><tr><td>time/iterations</td><td>23</td></tr><tr><td>time/time_elapsed</td><td>8</td></tr><tr><td>train/entropy</td><td>1e-05</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.00041</td></tr><tr><td>train/loss</td><td>0.0</td></tr><tr><td>train/n_updates</td><td>22</td></tr><tr><td>train/policy_gradient_loss</td><td>0.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/eifpmtip' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/eifpmtip</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251021_225910-eifpmtip/logs</code>

# %% [markdown]
# # 2 REINFORCE с базовым уровнем
# Градиент стратагии зависит от величины отдачи. Однако отдача может быть очень шумной оценкой $Q ^ {\pi} (s, a)$, особенно в средах с отложенными или редкими вознаграждениями. Этот шум приводит к высокой дисперсии в оценках градиента, что влечёт за собой сильные изменения стратегии. При этом обучение становится нестабильным, а сходимость медленной. Одним из способов снижения дисперсии является использование базового уровня $b(s)$. Базовый уровень $b(s)$ не зависит от действий, поэтому вычитание из оценки $Q ^ {\pi} (s, a)$ не приводит к смещению оценки градиента.
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [(G_t - b(s)) \nabla_\theta \ln \pi_\theta(a_t \vert s_t)]$$
#
# ## 2.1 REINFORCE с необучаемым базовым уровнем (средняя отдача)
# В некоторых случаях в качестве базового уровня достаточно использовать среднюю отдачу за предыдущие эпизоды. Даже такая простая эвристика может помочь стабилизировать процесс обучения на ранних этапах.

# %% [markdown]
# (3 балла)

# %%
# AverageReturnBuffer хранит статистику - среднюю отдачу по всем состояниям и эпизодам за время обучения
class AverageReturnBuffer(Buffer):
    def __init__(self, gamma: float = 0.99, device: Union[torch.device, str] = "cpu"):
        super().__init__(gamma, device)
        self.avg_returns = []

    def _get_mean(self, l):
        return sum(l) / max(1, len(l))

    def get_average_return(self):
        return self._get_mean(self.avg_returns)

    def compute_returns(self) -> None:
        super().compute_returns()
        self.avg_returns.append(self._get_mean(self.returns))

# %% [markdown]
# (1 балл)

# %%
class AverageReturnBaselineReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[AverageReturnBuffer] = AverageReturnBuffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda"):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class, policy_kwargs,
                         buffer_class, buffer_kwargs, seed, device)

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']

        # Получаем среднюю отдачу
        baseline = self.buffer.get_average_return()

        # Посчитать отдачи с учётом базового уровня
        returns = rollout_data.returns - baseline

        # Policy gradient loss
        policy_loss = -(returns * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        loss = policy_loss + entropy_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
            ("train/baseline", baseline)
        ])

# %%
run_algorithm(
    algorithm_class=AverageReturnBaselineReinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_simple-baseline'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='./reinforce_simple-baseline')
)
# Out:
# /home/vagiz/Desktop/desktop_vagiz/HSE/Programming/RL/.venv/lib/python3.12/site-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cuda device
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/home/vagiz/Desktop/desktop_vagiz/HSE/Programming/RL/practices/prac5/wandb/run-20251021_225921-jlhgaosq</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/jlhgaosq' target="_blank">reinforce_simple-baseline</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/jlhgaosq' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/jlhgaosq</a>
# /tmp/ipykernel_67619/3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# /tmp/ipykernel_67619/3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1630,
#     "num_episodes": 4,
#     "rollout/ep_len_mean": 407.5,
#     "rollout/ep_rew_mean": -71.22537994384766,
#     "time/fps": 1067,
#     "time/iterations": 4,
#     "time/time_elapsed": 1,
#     "train/baseline": -0.26718637385173144,
#     "train/entropy": 2.0786099433898926,
#     "train/entropy_loss": -0.0020786100067198277,
#     "train/grad_norm": 0.017963336780667305,
#     "train/loss": 0.09020087122917175,
#     "train/n_updates": 3,
#     "train/policy_gradient_loss": 0.09227947890758514
# }
# {
#     "global_step": 2028,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 405.6,
#     "rollout/ep_rew_mean": -76.8580093383789,
#     "time/fps": 1065,
#     "time/iterations": 5,
#     "time/time_elapsed": 1,
#     "train/baseline": -0.2142830259016906,
#     "train/entropy": 2.0791542530059814,
#     "train/entropy_loss": -0.0020791543647646904,
#     "train/grad_norm": 0.019048888236284256,
#     "train/loss": 0.328285813331604,
#     "train/n_updates": 4,
#     "train/policy_gradient_loss": 0.33036497235298157
# }
# {
#     "global_step": 3153,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 525.5,
#     "rollout/ep_rew_mean": -73.00260925292969,
#     "time/fps": 1073,
#     "time/iterations": 6,
#     "time/time_elapsed": 2,
#     "train/baseline": -0.22140905601539393,
#     "train/entropy": 2.0790514945983887,
#     "train/entropy_loss": -0.002079051686450839,
#     "train/grad_norm": 0.011306068859994411,
#     "train/loss": -0.06160340458154678,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": -0.059524353593587875
# }
# {
#     "global_step": 4235,
#     "num_episodes": 8,
#     "rollout/ep_len_mean": 529.375,
#     "rollout/ep_rew_mean": -43.99163818359375,
#     "time/fps": 1063,
#     "time/iterations": 8,
#     "time/time_elapsed": 3,
#     "train/baseline": -0.18944738539837527,
#     "train/entropy": 2.0783116817474365,
#     "train/entropy_loss": -0.002078311750665307,
#     "train/grad_norm": 0.01749185286462307,
#     "train/loss": 0.06512575596570969,
#     "train/n_updates": 7,
#     "train/policy_gradient_loss": 0.0672040656208992
# }
# {
#     "global_step": 5276,
#     "num_episodes": 11,
#     "rollout/ep_len_mean": 503.5,
#     "rollout/ep_rew_mean": -43.272193908691406,
#     "time/fps": 1067,
#     "time/iterations": 11,
#     "time/time_elapsed": 4,
#     "train/baseline": -0.15482386590681113,
#     "train/entropy": 2.0759568214416504,
#     "train/entropy_loss": -0.002075956901535392,
#     "train/grad_norm": 0.020103853195905685,
#     "train/loss": -0.2892971634864807,
#     "train/n_updates": 10,
#     "train/policy_gradient_loss": -0.28722119331359863
# }
# {
#     "global_step": 6520,
#     "num_episodes": 14,
#     "rollout/ep_len_mean": 489.0,
#     "rollout/ep_rew_mean": -15.44328498840332,
#     "time/fps": 1070,
#     "time/iterations": 14,
#     "time/time_elapsed": 6,
#     "train/baseline": -0.12046508697993569,
#     "train/entropy": 1.862394094467163,
#     "train/entropy_loss": -0.0018623941577970982,
#     "train/grad_norm": 0.2728738784790039,
#     "train/loss": 0.7074503302574158,
#     "train/n_updates": 13,
#     "train/policy_gradient_loss": 0.7093127369880676
# }
# {
#     "global_step": 7382,
#     "num_episodes": 16,
#     "rollout/ep_len_mean": 422.9,
#     "rollout/ep_rew_mean": -15.201278686523438,
#     "time/fps": 1072,
#     "time/iterations": 16,
#     "time/time_elapsed": 6,
#     "train/baseline": -0.11779124987889017,
#     "train/entropy": 2.077439546585083,
#     "train/entropy_loss": -0.0020774395670741796,
#     "train/grad_norm": 0.014390412718057632,
#     "train/loss": -0.05061572790145874,
#     "train/n_updates": 15,
#     "train/policy_gradient_loss": -0.048538289964199066
# }
# {
#     "global_step": 8031,
#     "num_episodes": 18,
#     "rollout/ep_len_mean": 379.6,
#     "rollout/ep_rew_mean": -34.20660400390625,
#     "time/fps": 1068,
#     "time/iterations": 18,
#     "time/time_elapsed": 7,
#     "train/baseline": -0.11930554840379666,
#     "train/entropy": 2.076504945755005,
#     "train/entropy_loss": -0.002076504984870553,
#     "train/grad_norm": 0.014512688852846622,
#     "train/loss": 0.1894243061542511,
#     "train/n_updates": 17,
#     "train/policy_gradient_loss": 0.19150081276893616
# }
# {
#     "global_step": 9296,
#     "num_episodes": 21,
#     "rollout/ep_len_mean": 402.0,
#     "rollout/ep_rew_mean": -22.872888565063477,
#     "time/fps": 1070,
#     "time/iterations": 21,
#     "time/time_elapsed": 8,
#     "train/baseline": -0.12432532317338163,
#     "train/entropy": 2.0770938396453857,
#     "train/entropy_loss": -0.0020770940463989973,
#     "train/grad_norm": 0.018886063247919083,
#     "train/loss": -0.008849842473864555,
#     "train/n_updates": 20,
#     "train/policy_gradient_loss": -0.006772748660296202
# }
# {
#     "global_step": 10756,
#     "num_episodes": 24,
#     "rollout/ep_len_mean": 423.6,
#     "rollout/ep_rew_mean": -51.00627517700195,
#     "time/fps": 1070,
#     "time/iterations": 24,
#     "time/time_elapsed": 10,
#     "train/baseline": -0.1267122203499496,
#     "train/entropy": 2.0775413513183594,
#     "train/entropy_loss": -0.0020775415468961,
#     "train/grad_norm": 0.019742559641599655,
#     "train/loss": 0.00984775647521019,
#     "train/n_updates": 23,
#     "train/policy_gradient_loss": 0.011925297789275646
# }
# {
#     "global_step": 11279,
#     "num_episodes": 25,
#     "rollout/ep_len_mean": 432.0,
#     "rollout/ep_rew_mean": -55.507713317871094,
#     "time/fps": 1071,
#     "time/iterations": 25,
#     "time/time_elapsed": 10,
#     "train/baseline": -0.12358906091928064,
#     "train/entropy": 2.077883720397949,
#     "train/entropy_loss": -0.0020778838079422712,
#     "train/grad_norm": 0.00863583292812109,
#     "train/loss": 0.14687179028987885,
#     "train/n_updates": 24,
#     "train/policy_gradient_loss": 0.14894966781139374
# }
# {
#     "global_step": 12147,
#     "num_episodes": 28,
#     "rollout/ep_len_mean": 411.6,
#     "rollout/ep_rew_mean": -63.999671936035156,
#     "time/fps": 1070,
#     "time/iterations": 28,
#     "time/time_elapsed": 11,
#     "train/baseline": -0.1369797152472211,
#     "train/entropy": 2.077627182006836,
#     "train/entropy_loss": -0.0020776272285729647,
#     "train/grad_norm": 0.014942432753741741,
#     "train/loss": -0.281634658575058,
#     "train/n_updates": 27,
#     "train/policy_gradient_loss": -0.2795570194721222
# }
# {
#     "global_step": 13346,
#     "num_episodes": 32,
#     "rollout/ep_len_mean": 369.8,
#     "rollout/ep_rew_mean": -61.711036682128906,
#     "time/fps": 1071,
#     "time/iterations": 32,
#     "time/time_elapsed": 12,
#     "train/baseline": -0.15269400676640665,
#     "train/entropy": 2.0766217708587646,
#     "train/entropy_loss": -0.0020766218658536673,
#     "train/grad_norm": 0.029760664328932762,
#     "train/loss": 0.0867253765463829,
#     "train/n_updates": 31,
#     "train/policy_gradient_loss": 0.08880199491977692
# }
# {
#     "global_step": 14054,
#     "num_episodes": 34,
#     "rollout/ep_len_mean": 329.8,
#     "rollout/ep_rew_mean": -67.88485717773438,
#     "time/fps": 1074,
#     "time/iterations": 34,
#     "time/time_elapsed": 13,
#     "train/baseline": -0.15390378873621038,
#     "train/entropy": 2.0736770629882812,
#     "train/entropy_loss": -0.0020736772567033768,
#     "train/grad_norm": 0.0339839868247509,
#     "train/loss": -0.21857966482639313,
#     "train/n_updates": 33,
#     "train/policy_gradient_loss": -0.2165059894323349
# }
# {
#     "global_step": 15094,
#     "num_episodes": 37,
#     "rollout/ep_len_mean": 316.9,
#     "rollout/ep_rew_mean": -27.2252197265625,
#     "time/fps": 1074,
#     "time/iterations": 37,
#     "time/time_elapsed": 14,
#     "train/baseline": -0.142450614691903,
#     "train/entropy": 2.067552089691162,
#     "train/entropy_loss": -0.0020675521809607744,
#     "train/grad_norm": 0.013275966979563236,
#     "train/loss": 0.03137063607573509,
#     "train/n_updates": 36,
#     "train/policy_gradient_loss": 0.03343818709254265
# }
# {
#     "global_step": 16097,
#     "num_episodes": 41,
#     "rollout/ep_len_mean": 310.9,
#     "rollout/ep_rew_mean": 62.237342834472656,
#     "time/fps": 1074,
#     "time/iterations": 41,
#     "time/time_elapsed": 14,
#     "train/baseline": -0.12401418294336342,
#     "train/entropy": 2.0344321727752686,
#     "train/entropy_loss": -0.002034432254731655,
#     "train/grad_norm": 0.21923871338367462,
#     "train/loss": 0.7102987766265869,
#     "train/n_updates": 40,
#     "train/policy_gradient_loss": 0.7123332023620605
# }
# {
#     "global_step": 17114,
#     "num_episodes": 47,
#     "rollout/ep_len_mean": 202.0,
#     "rollout/ep_rew_mean": 1433.5074462890625,
#     "time/fps": 1073,
#     "time/iterations": 47,
#     "time/time_elapsed": 15,
#     "train/baseline": 0.9100541488152892,
#     "train/entropy": 0.0001795971329556778,
#     "train/entropy_loss": -1.795971371620908e-07,
#     "train/grad_norm": 0.006234756670892239,
#     "train/loss": 0.00010687642497941852,
#     "train/n_updates": 46,
#     "train/policy_gradient_loss": 0.00010705602471716702
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▂▂▃▃▄▄▄▅▅▆▆▇▇██</td></tr><tr><td>num_episodes</td><td>▁▁▁▂▂▃▃▃▄▄▄▅▆▆▆▇█</td></tr><tr><td>rollout/ep_len_mean</td><td>▅▅██▇▇▆▅▅▆▆▅▅▄▃▃▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂█</td></tr><tr><td>time/fps</td><td>▄▂▇▁▄▅▇▄▅▅▆▅▆███▇</td></tr><tr><td>time/iterations</td><td>▁▁▁▂▂▃▃▃▄▄▄▅▆▆▆▇█</td></tr><tr><td>time/time_elapsed</td><td>▁▁▁▂▃▃▃▄▅▅▅▆▇▇▇▇█</td></tr><tr><td>train/baseline</td><td>▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂█</td></tr><tr><td>train/entropy</td><td>█████▇██████████▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁█</td></tr><tr><td>train/grad_norm</td><td>▁▁▁▁▁█▁▁▁▁▁▁▂▂▁▇▁</td></tr><tr><td>train/loss</td><td>▄▅▃▃▁█▃▄▃▃▄▁▄▁▃█▃</td></tr><tr><td>train/n_updates</td><td>▁▁▁▂▂▃▃▃▄▄▄▅▆▆▆▇█</td></tr><tr><td>train/policy_gradient_loss</td><td>▄▅▃▃▁█▃▄▃▃▄▁▄▁▃█▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>17114</td></tr><tr><td>num_episodes</td><td>47</td></tr><tr><td>rollout/ep_len_mean</td><td>202</td></tr><tr><td>rollout/ep_rew_mean</td><td>1433.50745</td></tr><tr><td>time/fps</td><td>1073</td></tr><tr><td>time/iterations</td><td>47</td></tr><tr><td>time/time_elapsed</td><td>15</td></tr><tr><td>train/baseline</td><td>0.91005</td></tr><tr><td>train/entropy</td><td>0.00018</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.00623</td></tr><tr><td>train/loss</td><td>0.00011</td></tr><tr><td>train/n_updates</td><td>46</td></tr><tr><td>train/policy_gradient_loss</td><td>0.00011</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_simple-baseline</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/jlhgaosq' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/jlhgaosq</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251021_225921-jlhgaosq/logs</code>

# %% [markdown]
# ## 2.2 REINFORCE с обучаемым базовым уровнем
# Чаще всего в качестве базового уровня применяется оценка функции полезности состояний $b(s) = v(s) = \mathbb{E}[G_t| s_t = s]$, получаемая с помощью нейросетевой аппроксимации. При этом величину $G_t - b(s_t)$ можно рассматривать как оценку функции преимущества (advantage) действия $a_t$ в состоянии $s_t$: $A(s_t, a_t) = Q(s_t, a_t) - V(s_t)$.
#
# #### Shared-encoder
# Модели стратегии и функции полезности могут обучаться в разных режимах — стратегия только on-policy (шаг обучения на текущей собранной подтраектории), а полезность on-policy или off-policy (шаг обучения на текущей подтраектории или на батче из replay buffer). Это с одной стороны привносит гибкость в обучение, с другой — усложняет его.
#
# Если обе модели обучаются on-policy, то имеет смысл объединить их сетки в одну и делать общий шаг обратного распространения ошибки. Однако, если они обучаются в разных режимах (и с разной частотой обновления), то велика вероятность, что их шаги обучения могут начать конфликтовать в случае общего тела — для такого варианта намного предпочтительнее разделить их на разные подсети (либо аккуратно настраивать гиперпарметры, чтобы стабилизировать обучение). В целом, рекомендуется использовать общий энкодер наблюдений, а далее как можно скорее разделять головы.

# %% [markdown]
# (2 балла)

# %%
class ValuePolicy(ReinforcePolicy):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space, lr: float,
                 optimizer_class: Type[torch.optim.Optimizer] = torch.optim.RMSprop,
                 optimizer_kwargs: Dict[str, Any] = {'eps': 1e-5}):
        # Добавить слой для вычисления полезности состояний
        super().__init__(observation_space, action_space, lr, optimizer_class, optimizer_kwargs)
        self.in_shape = observation_space.shape
        self.in_features = torch.prod(torch.tensor(self.in_shape)).item()
        self.value_net = nn.Linear(self.in_features, 1)

    def evaluate_actions(self, obs: torch.Tensor, actions_taken: torch.Tensor) -> Dict[str, torch.Tensor]:
        # Метод должен возвращать словарь с 'features', 'log_prob', 'entropy' и 'values' - полезность obs
        evaluations = super().evaluate_actions(obs, actions_taken)

        obs_flatten = obs.reshape(-1, self.in_features)
        evaluations['value'] = self.value_net(obs_flatten.float()).squeeze()
        return evaluations

# %% [markdown]
# (1 балл)

# %%
class ValueBaselineReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ValuePolicy] = ValuePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[Buffer] = Buffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda", vf_coef: float = 0.5,):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class,
                         policy_kwargs, buffer_class, buffer_kwargs, seed, device)
        self.vf_coef = vf_coef

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']
        values = policy_output['value']
        advantages = rollout_data.returns - values.detach()
        baseline = values.mean().item()

        # Policy gradient loss
        policy_loss = -(advantages * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        # Value loss с коэффициентов self.vf_coef
        value_loss = -self.vf_coef * advantages.square().mean()

        loss = policy_loss + entropy_loss + value_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
            ("train/baseline", baseline), ("train/value_loss", value_loss.item())
        ])

# %%
run_algorithm(
    algorithm_class=ValueBaselineReinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_value-baseline'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_value-baseline')
)
# Out:
# /home/vagiz/Desktop/desktop_vagiz/HSE/Programming/RL/.venv/lib/python3.12/site-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cuda device
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/home/vagiz/Desktop/desktop_vagiz/HSE/Programming/RL/practices/prac5/wandb/run-20251021_225941-kghvgq5n</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/kghvgq5n' target="_blank">reinforce_value-baseline</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/kghvgq5n' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/kghvgq5n</a>
# /tmp/ipykernel_67619/3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# /tmp/ipykernel_67619/3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1087,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 362.3333333333333,
#     "rollout/ep_rew_mean": -103.1655502319336,
#     "time/fps": 1057,
#     "time/iterations": 3,
#     "time/time_elapsed": 1,
#     "train/baseline": -33.44287109375,
#     "train/entropy": 2.076578378677368,
#     "train/entropy_loss": -0.0020765785593539476,
#     "train/grad_norm": 3.2516825199127197,
#     "train/loss": -511.9028015136719,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": 68.7785873413086,
#     "train/value_loss": -580.6793212890625
# }
# {
#     "global_step": 2350,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 391.6666666666667,
#     "rollout/ep_rew_mean": -82.87866973876953,
#     "time/fps": 1072,
#     "time/iterations": 6,
#     "time/time_elapsed": 2,
#     "train/baseline": -30.86522102355957,
#     "train/entropy": 1.9839787483215332,
#     "train/entropy_loss": -0.001983978785574436,
#     "train/grad_norm": 7.511319637298584,
#     "train/loss": -439.50079345703125,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": 61.141876220703125,
#     "train/value_loss": -500.64068603515625
# }
# {
#     "global_step": 4450,
#     "num_episodes": 7,
#     "rollout/ep_len_mean": 635.7142857142857,
#     "rollout/ep_rew_mean": -26.951921463012695,
#     "time/fps": 1069,
#     "time/iterations": 7,
#     "time/time_elapsed": 4,
#     "train/baseline": -30.9615421295166,
#     "train/entropy": 2.047447443008423,
#     "train/entropy_loss": -0.0020474474877119064,
#     "train/grad_norm": 3.128009796142578,
#     "train/loss": -446.1723327636719,
#     "train/n_updates": 6,
#     "train/policy_gradient_loss": 63.32276153564453,
#     "train/value_loss": -509.4930419921875
# }
# {
#     "global_step": 4712,
#     "num_episodes": 8,
#     "rollout/ep_len_mean": 589.0,
#     "rollout/ep_rew_mean": -25.869924545288086,
#     "time/fps": 1059,
#     "time/iterations": 8,
#     "time/time_elapsed": 4,
#     "train/baseline": -28.85850715637207,
#     "train/entropy": 2.0620784759521484,
#     "train/entropy_loss": -0.0020620785653591156,
#     "train/grad_norm": 0.5913724303245544,
#     "train/loss": -400.3948669433594,
#     "train/n_updates": 7,
#     "train/policy_gradient_loss": 59.80756759643555,
#     "train/value_loss": -460.20037841796875
# }
# {
#     "global_step": 5215,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 579.4444444444445,
#     "rollout/ep_rew_mean": -22.351736068725586,
#     "time/fps": 1064,
#     "time/iterations": 9,
#     "time/time_elapsed": 4,
#     "train/baseline": -32.12261199951172,
#     "train/entropy": 2.0610337257385254,
#     "train/entropy_loss": -0.0020610338542610407,
#     "train/grad_norm": 3.679150104522705,
#     "train/loss": -482.8414001464844,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": 65.72505950927734,
#     "train/value_loss": -548.5643920898438
# }
# {
#     "global_step": 6369,
#     "num_episodes": 12,
#     "rollout/ep_len_mean": 579.8,
#     "rollout/ep_rew_mean": -6.9166975021362305,
#     "time/fps": 1061,
#     "time/iterations": 12,
#     "time/time_elapsed": 6,
#     "train/baseline": -26.774402618408203,
#     "train/entropy": 1.763075828552246,
#     "train/entropy_loss": -0.0017630759393796325,
#     "train/grad_norm": 8.388294219970703,
#     "train/loss": -325.3792419433594,
#     "train/n_updates": 11,
#     "train/policy_gradient_loss": 47.887847900390625,
#     "train/value_loss": -373.26531982421875
# }
# {
#     "global_step": 7143,
#     "num_episodes": 14,
#     "rollout/ep_len_mean": 548.2,
#     "rollout/ep_rew_mean": 16.646953582763672,
#     "time/fps": 1059,
#     "time/iterations": 14,
#     "time/time_elapsed": 6,
#     "train/baseline": -27.686960220336914,
#     "train/entropy": 1.8614213466644287,
#     "train/entropy_loss": -0.0018614213913679123,
#     "train/grad_norm": 9.718814849853516,
#     "train/loss": -351.3193359375,
#     "train/n_updates": 13,
#     "train/policy_gradient_loss": 51.22025680541992,
#     "train/value_loss": -402.5377197265625
# }
# {
#     "global_step": 8219,
#     "num_episodes": 17,
#     "rollout/ep_len_mean": 376.9,
#     "rollout/ep_rew_mean": -8.49559497833252,
#     "time/fps": 1058,
#     "time/iterations": 17,
#     "time/time_elapsed": 7,
#     "train/baseline": -29.045228958129883,
#     "train/entropy": 1.9620434045791626,
#     "train/entropy_loss": -0.0019620435778051615,
#     "train/grad_norm": 6.468438148498535,
#     "train/loss": -401.3862609863281,
#     "train/n_updates": 16,
#     "train/policy_gradient_loss": 56.208370208740234,
#     "train/value_loss": -457.5926818847656
# }
# {
#     "global_step": 9012,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 357.0,
#     "rollout/ep_rew_mean": 19.429962158203125,
#     "time/fps": 1056,
#     "time/iterations": 20,
#     "time/time_elapsed": 8,
#     "train/baseline": -24.784595489501953,
#     "train/entropy": 1.4619505405426025,
#     "train/entropy_loss": -0.001461950596421957,
#     "train/grad_norm": 5.356648921966553,
#     "train/loss": -301.99005126953125,
#     "train/n_updates": 19,
#     "train/policy_gradient_loss": 36.818870544433594,
#     "train/value_loss": -338.8074645996094
# }
# {
#     "global_step": 10075,
#     "num_episodes": 25,
#     "rollout/ep_len_mean": 261.9,
#     "rollout/ep_rew_mean": 207.2355499267578,
#     "time/fps": 1051,
#     "time/iterations": 25,
#     "time/time_elapsed": 9,
#     "train/baseline": -23.564516067504883,
#     "train/entropy": 1.052337408065796,
#     "train/entropy_loss": -0.0010523374658077955,
#     "train/grad_norm": 10.838146209716797,
#     "train/loss": -303.41070556640625,
#     "train/n_updates": 24,
#     "train/policy_gradient_loss": 26.13352394104004,
#     "train/value_loss": -329.5431823730469
# }
# {
#     "global_step": 11019,
#     "num_episodes": 29,
#     "rollout/ep_len_mean": 219.5,
#     "rollout/ep_rew_mean": 254.82296752929688,
#     "time/fps": 1047,
#     "time/iterations": 29,
#     "time/time_elapsed": 10,
#     "train/baseline": -26.083152770996094,
#     "train/entropy": 1.4908477067947388,
#     "train/entropy_loss": -0.001490847789682448,
#     "train/grad_norm": 16.105785369873047,
#     "train/loss": -310.4660949707031,
#     "train/n_updates": 28,
#     "train/policy_gradient_loss": 40.51659393310547,
#     "train/value_loss": -350.981201171875
# }
# {
#     "global_step": 12081,
#     "num_episodes": 32,
#     "rollout/ep_len_mean": 265.0,
#     "rollout/ep_rew_mean": 155.74032592773438,
#     "time/fps": 1045,
#     "time/iterations": 32,
#     "time/time_elapsed": 11,
#     "train/baseline": -30.747447967529297,
#     "train/entropy": 1.8262652158737183,
#     "train/entropy_loss": -0.001826265244744718,
#     "train/grad_norm": 12.37861442565918,
#     "train/loss": -435.2039489746094,
#     "train/n_updates": 31,
#     "train/policy_gradient_loss": 54.327232360839844,
#     "train/value_loss": -489.52935791015625
# }
# {
#     "global_step": 13059,
#     "num_episodes": 36,
#     "rollout/ep_len_mean": 275.4,
#     "rollout/ep_rew_mean": 75.89099884033203,
#     "time/fps": 1047,
#     "time/iterations": 36,
#     "time/time_elapsed": 12,
#     "train/baseline": -26.646509170532227,
#     "train/entropy": 1.7017440795898438,
#     "train/entropy_loss": -0.0017017441568896174,
#     "train/grad_norm": 19.45328140258789,
#     "train/loss": -367.5031433105469,
#     "train/n_updates": 35,
#     "train/policy_gradient_loss": 44.43303680419922,
#     "train/value_loss": -411.9344787597656
# }
# {
#     "global_step": 14093,
#     "num_episodes": 42,
#     "rollout/ep_len_mean": 201.2,
#     "rollout/ep_rew_mean": 951.2283935546875,
#     "time/fps": 1049,
#     "time/iterations": 42,
#     "time/time_elapsed": 13,
#     "train/baseline": -26.313610076904297,
#     "train/entropy": 0.04763592407107353,
#     "train/entropy_loss": -4.763592733070254e-05,
#     "train/grad_norm": 11.42849349975586,
#     "train/loss": -647.9354858398438,
#     "train/n_updates": 41,
#     "train/policy_gradient_loss": 0.24206866323947906,
#     "train/value_loss": -648.177490234375
# }
# {
#     "global_step": 15108,
#     "num_episodes": 48,
#     "rollout/ep_len_mean": 167.4,
#     "rollout/ep_rew_mean": 2125.29638671875,
#     "time/fps": 1050,
#     "time/iterations": 48,
#     "time/time_elapsed": 14,
#     "train/baseline": -24.941171646118164,
#     "train/entropy": 0.0001793935807654634,
#     "train/entropy_loss": -1.7939359509000496e-07,
#     "train/grad_norm": 0.03739728406071663,
#     "train/loss": -597.0988159179688,
#     "train/n_updates": 47,
#     "train/policy_gradient_loss": 0.00045961877913214266,
#     "train/value_loss": -597.0993041992188
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▃▃▃▄▄▅▅▅▆▆▇▇█</td></tr><tr><td>num_episodes</td><td>▁▁▂▂▂▂▃▃▄▄▅▆▆▇█</td></tr><tr><td>rollout/ep_len_mean</td><td>▄▄█▇▇▇▇▄▄▂▂▂▃▂▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▁▁▁▂▂▂▂▄█</td></tr><tr><td>time/fps</td><td>▄█▇▅▆▅▅▄▄▃▂▁▂▂▂</td></tr><tr><td>time/iterations</td><td>▁▁▂▂▂▂▃▃▄▄▅▆▆▇█</td></tr><tr><td>time/time_elapsed</td><td>▁▂▃▃▃▄▄▄▅▅▆▆▇▇█</td></tr><tr><td>train/baseline</td><td>▁▃▃▄▂▆▅▄▇█▆▃▆▆▇</td></tr><tr><td>train/entropy</td><td>█████▇▇█▆▅▆▇▇▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▂▂▁▃▄▃▂▂██</td></tr><tr><td>train/grad_norm</td><td>▂▄▂▁▂▄▄▃▃▅▇▅█▅▁</td></tr><tr><td>train/loss</td><td>▄▅▅▆▄█▇▆███▅▇▁▂</td></tr><tr><td>train/n_updates</td><td>▁▁▂▂▂▂▃▃▄▄▅▆▆▇█</td></tr><tr><td>train/policy_gradient_loss</td><td>█▇▇▇█▆▆▇▅▄▅▇▆▁▁</td></tr><tr><td>train/value_loss</td><td>▂▄▄▅▃▇▆▅███▄▆▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>15108</td></tr><tr><td>num_episodes</td><td>48</td></tr><tr><td>rollout/ep_len_mean</td><td>167.4</td></tr><tr><td>rollout/ep_rew_mean</td><td>2125.29639</td></tr><tr><td>time/fps</td><td>1050</td></tr><tr><td>time/iterations</td><td>48</td></tr><tr><td>time/time_elapsed</td><td>14</td></tr><tr><td>train/baseline</td><td>-24.94117</td></tr><tr><td>train/entropy</td><td>0.00018</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.0374</td></tr><tr><td>train/loss</td><td>-597.09882</td></tr><tr><td>train/n_updates</td><td>47</td></tr><tr><td>train/policy_gradient_loss</td><td>0.00046</td></tr><tr><td>train/value_loss</td><td>-597.0993</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_value-baseline</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/kghvgq5n' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/kghvgq5n</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251021_225941-kghvgq5n/logs</code>

# %% [markdown]
# # 3 REINFORCE с разбиением на мини-батчи
# В предыдущих реализациях по данным одной собранной траетории стратегия обновлялась только один раз. Попробуем разбить траекторию на мини-батчи и обучаться на одной траектории в течение нескольких эпох. С одной стороны это должно привести к ускорению обучения, поскольку модели будут обновляться чаще. С другой стороны такая схема обучения отходит от on-policy режима.

# %%
class BatchedReturnBuffer(AverageReturnBuffer):
    def __init__(self, gamma: float = 0.99, device: Union[torch.device, str] = "cpu"):
        super().__init__(gamma, device)
        self.generator_ready = None

    def reset(self) -> None:
        super().reset()
        self.generator_ready = False

    def get(self, batch_size: Optional[Union[int, float]] = None) -> Generator[BufferSamples, None, None]:
        buffer_size = self.size()
        indices = np.random.permutation(buffer_size)
        if not self.generator_ready:
            self.observations = np.asarray(self.observations)
            self.actions = np.asarray(self.actions)
            self.returns = np.asarray(self.returns, dtype=np.float32)
            self.generator_ready = True

        if batch_size is None or math.isinf(batch_size):
            batch_size = buffer_size

        start_idx = 0
        while start_idx < buffer_size:
            yield self._get_samples(indices[start_idx: start_idx + batch_size])
            start_idx += batch_size

# %% [markdown]
# (3 балла)

# %%
class BatchedAverageReturnReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[BatchedReturnBuffer] = BatchedReturnBuffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda", batch_size: Union[int, float] = 64, n_epochs: int = 1):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class, policy_kwargs,
                         buffer_class, buffer_kwargs, seed, device)
        self.batch_size = batch_size
        self.n_epochs = n_epochs

    def train(self) -> None:
        # В train выполняется self.n_epochs проходов по буферу.
        # Данные из буфера сэмплируются батчами размера self.batch_size: self.buffer.get(self.batch_size).
        # Тело функции аналогично методу train в AverageReturnBaselineReinforce,
        # единственное отличие - несколько эпох обучения и обучение на батчах.
        self.policy.set_training_mode(True)

        for rollout_data in self.buffer.get(self.batch_size):
            actions = rollout_data.actions.long()
            policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
            log_prob = policy_output['log_prob']
            entropy = policy_output['entropy']
    
            # Получаем среднюю отдачу
            baseline = self.buffer.get_average_return()
    
            # Посчитать отдачи с учётом базового уровня
            returns = rollout_data.returns - baseline
    
            # Policy gradient loss
            policy_loss = -(returns * log_prob).mean()
    
            # Entropy loss
            entropy = torch.mean(entropy)
            entropy_loss = -self.ent_coef * entropy
    
            loss = policy_loss + entropy_loss
    
            # Optimization step
            self.policy.optimizer.zero_grad()
            loss.backward()
            grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
            self.policy.optimizer.step()
    
            self._n_updates += 1

            self.log_dict = dict([
                ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
                ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
                ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
                ("train/baseline", baseline)
            ])

# %% [markdown]
# ### Одна эпоха обучения

# %%
run_algorithm(
    algorithm_class=BatchedAverageReturnReinforce,
    algorithm_kwargs=dict(seed=0, batch_size=64, n_epochs=1),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_batch-epoch-1'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_batch-epoch-1')
)
# Out:
# /home/vagiz/Desktop/desktop_vagiz/HSE/Programming/RL/.venv/lib/python3.12/site-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cuda device
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/home/vagiz/Desktop/desktop_vagiz/HSE/Programming/RL/practices/prac5/wandb/run-20251021_225959-pb0xdpfs</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/pb0xdpfs' target="_blank">reinforce_batch-epoch-1</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/pb0xdpfs' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/pb0xdpfs</a>
# /tmp/ipykernel_67619/3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# /tmp/ipykernel_67619/3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 3040,
#     "num_episodes": 4,
#     "rollout/ep_len_mean": 760.0,
#     "rollout/ep_rew_mean": -69.38506317138672,
#     "time/fps": 1069,
#     "time/iterations": 4,
#     "time/time_elapsed": 2,
#     "train/baseline": -0.29604055137859664,
#     "train/entropy": 2.0778117179870605,
#     "train/entropy_loss": -0.002077811863273382,
#     "train/grad_norm": 0.05093594640493393,
#     "train/loss": 0.02000444382429123,
#     "train/n_updates": 16,
#     "train/policy_gradient_loss": 0.0220822561532259
# }
# {
#     "global_step": 3368,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 673.6,
#     "rollout/ep_rew_mean": -69.79519653320312,
#     "time/fps": 1036,
#     "time/iterations": 5,
#     "time/time_elapsed": 3,
#     "train/baseline": -0.2188842593936303,
#     "train/entropy": 2.0779590606689453,
#     "train/entropy_loss": -0.002077959245070815,
#     "train/grad_norm": 0.06602391600608826,
#     "train/loss": 0.42735975980758667,
#     "train/n_updates": 49,
#     "train/policy_gradient_loss": 0.4294377267360687
# }
# {
#     "global_step": 3570,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 595.0,
#     "rollout/ep_rew_mean": -65.9427261352539,
#     "time/fps": 1032,
#     "time/iterations": 6,
#     "time/time_elapsed": 3,
#     "train/baseline": -0.21357153099192422,
#     "train/entropy": 2.0738704204559326,
#     "train/entropy_loss": -0.0020738705061376095,
#     "train/grad_norm": 0.162660151720047,
#     "train/loss": 0.11182999610900879,
#     "train/n_updates": 55,
#     "train/policy_gradient_loss": 0.11390386521816254
# }
# {
#     "global_step": 4165,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 462.77777777777777,
#     "rollout/ep_rew_mean": 271.18206787109375,
#     "time/fps": 1025,
#     "time/iterations": 9,
#     "time/time_elapsed": 4,
#     "train/baseline": -0.002150703458169409,
#     "train/entropy": 1.810356855392456,
#     "train/entropy_loss": -0.0018103569746017456,
#     "train/grad_norm": 2.762448310852051,
#     "train/loss": 0.898123025894165,
#     "train/n_updates": 65,
#     "train/policy_gradient_loss": 0.899933397769928
# }
# {
#     "global_step": 5167,
#     "num_episodes": 15,
#     "rollout/ep_len_mean": 179.9,
#     "rollout/ep_rew_mean": 1181.6292724609375,
#     "time/fps": 1022,
#     "time/iterations": 15,
#     "time/time_elapsed": 5,
#     "train/baseline": 2.16510745005156,
#     "train/entropy": 0.03634455427527428,
#     "train/entropy_loss": -3.6344554246170446e-05,
#     "train/grad_norm": 0.1899934560060501,
#     "train/loss": 0.005221233703196049,
#     "train/n_updates": 85,
#     "train/policy_gradient_loss": 0.0052575781010091305
# }
# {
#     "global_step": 6002,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 164.5,
#     "rollout/ep_rew_mean": 1814.8890380859375,
#     "time/fps": 1022,
#     "time/iterations": 20,
#     "time/time_elapsed": 5,
#     "train/baseline": 4.0001518494122665,
#     "train/entropy": 0.00033007957972586155,
#     "train/entropy_loss": -3.300795867744455e-07,
#     "train/grad_norm": 0.008162615820765495,
#     "train/loss": 0.00013459072215482593,
#     "train/n_updates": 100,
#     "train/policy_gradient_loss": 0.00013492080324795097
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▂▄▆█</td></tr><tr><td>num_episodes</td><td>▁▁▂▃▆█</td></tr><tr><td>rollout/ep_len_mean</td><td>█▇▆▅▁▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▂▆█</td></tr><tr><td>time/fps</td><td>█▃▂▁▁▁</td></tr><tr><td>time/iterations</td><td>▁▁▂▃▆█</td></tr><tr><td>time/time_elapsed</td><td>▁▃▃▆██</td></tr><tr><td>train/baseline</td><td>▁▁▁▁▅█</td></tr><tr><td>train/entropy</td><td>███▇▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▂██</td></tr><tr><td>train/grad_norm</td><td>▁▁▁█▁▁</td></tr><tr><td>train/loss</td><td>▁▄▂█▁▁</td></tr><tr><td>train/n_updates</td><td>▁▄▄▅▇█</td></tr><tr><td>train/policy_gradient_loss</td><td>▁▄▂█▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>6002</td></tr><tr><td>num_episodes</td><td>20</td></tr><tr><td>rollout/ep_len_mean</td><td>164.5</td></tr><tr><td>rollout/ep_rew_mean</td><td>1814.88904</td></tr><tr><td>time/fps</td><td>1022</td></tr><tr><td>time/iterations</td><td>20</td></tr><tr><td>time/time_elapsed</td><td>5</td></tr><tr><td>train/baseline</td><td>4.00015</td></tr><tr><td>train/entropy</td><td>0.00033</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.00816</td></tr><tr><td>train/loss</td><td>0.00013</td></tr><tr><td>train/n_updates</td><td>100</td></tr><tr><td>train/policy_gradient_loss</td><td>0.00013</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_batch-epoch-1</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/pb0xdpfs' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/pb0xdpfs</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251021_225959-pb0xdpfs/logs</code>

# %% [markdown]
# ### Две эпохи обучения

# %%
run_algorithm(
    algorithm_class=BatchedAverageReturnReinforce,
    algorithm_kwargs=dict(seed=0, batch_size=64, n_epochs=2),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_batch-epoch-2'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_batch-epoch-2')
)
# Out:
# /home/vagiz/Desktop/desktop_vagiz/HSE/Programming/RL/.venv/lib/python3.12/site-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cuda device
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/home/vagiz/Desktop/desktop_vagiz/HSE/Programming/RL/practices/prac5/wandb/run-20251021_230009-e3t0s45q</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/e3t0s45q' target="_blank">reinforce_batch-epoch-2</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/e3t0s45q' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/e3t0s45q</a>
# /tmp/ipykernel_67619/3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# /tmp/ipykernel_67619/3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 3040,
#     "num_episodes": 4,
#     "rollout/ep_len_mean": 760.0,
#     "rollout/ep_rew_mean": -69.38506317138672,
#     "time/fps": 1083,
#     "time/iterations": 4,
#     "time/time_elapsed": 2,
#     "train/baseline": -0.29604055137859664,
#     "train/entropy": 2.0778117179870605,
#     "train/entropy_loss": -0.002077811863273382,
#     "train/grad_norm": 0.05093594640493393,
#     "train/loss": 0.02000444382429123,
#     "train/n_updates": 16,
#     "train/policy_gradient_loss": 0.0220822561532259
# }
# {
#     "global_step": 3368,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 673.6,
#     "rollout/ep_rew_mean": -69.79519653320312,
#     "time/fps": 1047,
#     "time/iterations": 5,
#     "time/time_elapsed": 3,
#     "train/baseline": -0.2188842593936303,
#     "train/entropy": 2.0779590606689453,
#     "train/entropy_loss": -0.002077959245070815,
#     "train/grad_norm": 0.06602391600608826,
#     "train/loss": 0.42735975980758667,
#     "train/n_updates": 49,
#     "train/policy_gradient_loss": 0.4294377267360687
# }
# {
#     "global_step": 3570,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 595.0,
#     "rollout/ep_rew_mean": -65.9427261352539,
#     "time/fps": 1043,
#     "time/iterations": 6,
#     "time/time_elapsed": 3,
#     "train/baseline": -0.21357153099192422,
#     "train/entropy": 2.0738704204559326,
#     "train/entropy_loss": -0.0020738705061376095,
#     "train/grad_norm": 0.162660151720047,
#     "train/loss": 0.11182999610900879,
#     "train/n_updates": 55,
#     "train/policy_gradient_loss": 0.11390386521816254
# }
# {
#     "global_step": 4165,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 462.77777777777777,
#     "rollout/ep_rew_mean": 271.18206787109375,
#     "time/fps": 1040,
#     "time/iterations": 9,
#     "time/time_elapsed": 4,
#     "train/baseline": -0.002150703458169409,
#     "train/entropy": 1.810356855392456,
#     "train/entropy_loss": -0.0018103569746017456,
#     "train/grad_norm": 2.762448310852051,
#     "train/loss": 0.898123025894165,
#     "train/n_updates": 65,
#     "train/policy_gradient_loss": 0.899933397769928
# }
# {
#     "global_step": 5167,
#     "num_episodes": 15,
#     "rollout/ep_len_mean": 179.9,
#     "rollout/ep_rew_mean": 1181.6292724609375,
#     "time/fps": 1032,
#     "time/iterations": 15,
#     "time/time_elapsed": 5,
#     "train/baseline": 2.16510745005156,
#     "train/entropy": 0.03634455427527428,
#     "train/entropy_loss": -3.6344554246170446e-05,
#     "train/grad_norm": 0.1899934560060501,
#     "train/loss": 0.005221233703196049,
#     "train/n_updates": 85,
#     "train/policy_gradient_loss": 0.0052575781010091305
# }
# {
#     "global_step": 6002,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 164.5,
#     "rollout/ep_rew_mean": 1814.8890380859375,
#     "time/fps": 1036,
#     "time/iterations": 20,
#     "time/time_elapsed": 5,
#     "train/baseline": 4.0001518494122665,
#     "train/entropy": 0.00033007957972586155,
#     "train/entropy_loss": -3.300795867744455e-07,
#     "train/grad_norm": 0.008162615820765495,
#     "train/loss": 0.00013459072215482593,
#     "train/n_updates": 100,
#     "train/policy_gradient_loss": 0.00013492080324795097
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▂▄▆█</td></tr><tr><td>num_episodes</td><td>▁▁▂▃▆█</td></tr><tr><td>rollout/ep_len_mean</td><td>█▇▆▅▁▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▂▆█</td></tr><tr><td>time/fps</td><td>█▃▃▂▁▂</td></tr><tr><td>time/iterations</td><td>▁▁▂▃▆█</td></tr><tr><td>time/time_elapsed</td><td>▁▃▃▆██</td></tr><tr><td>train/baseline</td><td>▁▁▁▁▅█</td></tr><tr><td>train/entropy</td><td>███▇▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▂██</td></tr><tr><td>train/grad_norm</td><td>▁▁▁█▁▁</td></tr><tr><td>train/loss</td><td>▁▄▂█▁▁</td></tr><tr><td>train/n_updates</td><td>▁▄▄▅▇█</td></tr><tr><td>train/policy_gradient_loss</td><td>▁▄▂█▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>6002</td></tr><tr><td>num_episodes</td><td>20</td></tr><tr><td>rollout/ep_len_mean</td><td>164.5</td></tr><tr><td>rollout/ep_rew_mean</td><td>1814.88904</td></tr><tr><td>time/fps</td><td>1036</td></tr><tr><td>time/iterations</td><td>20</td></tr><tr><td>time/time_elapsed</td><td>5</td></tr><tr><td>train/baseline</td><td>4.00015</td></tr><tr><td>train/entropy</td><td>0.00033</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.00816</td></tr><tr><td>train/loss</td><td>0.00013</td></tr><tr><td>train/n_updates</td><td>100</td></tr><tr><td>train/policy_gradient_loss</td><td>0.00013</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_batch-epoch-2</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/e3t0s45q' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/e3t0s45q</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251021_230009-e3t0s45q/logs</code>
